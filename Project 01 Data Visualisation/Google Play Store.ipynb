# %% [markdown]
# # Google Playstore Case Study

# %% [markdown]
# In this module you’ll be learning data visualisation with the help of a case study. This will enable you to understand how visualisation aids you in solving business problems.

# %% [markdown]
# ### Session 1 - Introduction to Data Visualisation

# %%
#import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the dataset and check the first five rows
inp0 =inp0 = pd.read_csv("/content/hourly_wages_Data_Camp.csv")
inp0.head()
# Out:
#    wage_per_hour  union  education_yrs  experience_yrs  age  female  marr  \
# 0           5.10      0              8              21   35       1     1
# 1           4.95      0              9              42   57       1     1
# 2           6.67      0             12               1   19       0     0
# 3           4.00      0             12               4   22       0     0
# 4           7.50      0             12              17   35       0     1
#
#    south  manufacturing  construction
# 0      0              1             0
# 1      0              1             0
# 2      0              1             0
# 3      0              0             0
# 4      0              0             0

# %%
#Check the shape of the dataframe
inp0.shape
# Out:
# (534, 10)

# %% [markdown]
# ### Data Handling and Cleaning

# %% [markdown]
# The first few steps involve making sure that there are no __missing values__ or __incorrect data types__ before we proceed to the analysis stage. These aforementioned problems are handled as follows:
#
#  - For Missing Values: Some common techniques to treat this issue are
#     - Dropping the rows containing the missing values
#     - Imputing the missing values
#     - Keep the missing values if they don't affect the analysis
#
#
#  - Incorrect Data Types:
#     - Clean certain values
#     - Clean and convert an entire column

# %%
#Check the datatypes of all the columns of the dataframe
inp0.dtypes
# Out:
# wage_per_hour     float64
# union               int64
# education_yrs       int64
# experience_yrs      int64
# age                 int64
# female              int64
# marr                int64
# south               int64
# manufacturing       int64
# construction        int64
# dtype: object

# %% [markdown]
# #### Missing Value Treatment

# %%
#Check the number of null values in the columns
inp0.isnull().sum()
# Out:
# wage_per_hour     0
# union             0
# education_yrs     0
# experience_yrs    0
# age               0
# female            0
# marr              0
# south             0
# manufacturing     0
# construction      0
# dtype: int64

# %% [markdown]
# Handling Missing Values for Wage per Hour
#
# Wage per hour is the target variable.
#
# Drop the records having missing values in the wage_per_hour column.

# %%
#Drop the rows having null values in the Rating field
inp0 = inp0.dropna(subset=['wage_per_hour'])



#Check the shape of the dataframe
inp0.shape
# Out:
# (534, 10)

# %%
# Check the number of null values in the wage_per_hour column again to cross-verify
inp0['wage_per_hour'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Question
# Check the number of null values in each column and find the total number of null values

inp0.isnull().sum()      # Null values in each column
inp0.isnull().sum().sum()  # Total null values in the entire DataFrame
# Out:
# np.int64(0)

# %%
# Inspect the dataset for any remaining missing values
inp0.isnull().sum()
# Out:
# wage_per_hour     0
# union             0
# education_yrs     0
# experience_yrs    0
# age               0
# female            0
# marr              0
# south             0
# manufacturing     0
# construction      0
# dtype: int64

# %%
# Verify that there are no invalid or shifted records in the dataset
inp0.head()

# Check the null values in the dataset again to cross-verify
inp0.isnull().sum()
# Out:
# wage_per_hour     0
# union             0
# education_yrs     0
# experience_yrs    0
# age               0
# female            0
# marr              0
# south             0
# manufacturing     0
# construction      0
# dtype: int64

# %%
# No missing values found in the dataset; therefore, no imputation is required

# %%
# Check the most common value in the union column
inp0['union'].mode()[0]
# Out:
# np.int64(0)

# %%
# No missing values found in the union column; no imputation required.

# %%
# Check the null values in the dataset again to cross-verify
inp0.isnull().sum()
# Out:
# wage_per_hour     0
# union             0
# education_yrs     0
# experience_yrs    0
# age               0
# female            0
# marr              0
# south             0
# manufacturing     0
# construction      0
# dtype: int64

# %%
#Check the nulls in the entire dataframe again

# %%
# Check the most common value in the female column
inp0['female'].mode()
# Out:
# 0    0
# Name: female, dtype: int64

# %%
# No missing values found in the female column; no replacement is required.

# %%
# Question: Check the most common value in the female column again
inp0['female'].mode()[0]
# Out:
# np.int64(0)

# %% [markdown]
# #### Handling Incorrect Data Types

# %%
# Check the datatypes of all the columns
inp0.dtypes
# Out:
# wage_per_hour     float64
# union               int64
# education_yrs       int64
# experience_yrs      int64
# age                 int64
# female              int64
# marr                int64
# south               int64
# manufacturing       int64
# construction        int64
# dtype: object

# %%
# Question - Calculate the average wage_per_hour of employees who are members of a union
inp0[inp0['union'] == 1]['wage_per_hour'].mean()
# Out:
# np.float64(10.798124999999999)

# %%
# Analyse the wage_per_hour column to check for any data quality issues
inp0['wage_per_hour'].describe()
# Out:
# count    534.000000
# mean       9.024064
# std        5.139097
# min        1.000000
# 25%        5.250000
# 50%        7.780000
# 75%       11.250000
# max       44.500000
# Name: wage_per_hour, dtype: float64

# %%
# Write a function to clean the wage_per_hour values

def clean_wage(x):
    return float(x)

inp0['wage_per_hour'] = inp0['wage_per_hour'].apply(clean_wage)

# %%
# Verify the data type of the wage_per_hour column once again
inp0['wage_per_hour'].dtype
# Out:
# dtype('float64')

# %%
# Analyse the experience_yrs column
inp0['experience_yrs'].describe()
# Out:
# count    534.000000
# mean      17.822097
# std       12.379710
# min        0.000000
# 25%        8.000000
# 50%       15.000000
# 75%       26.000000
# max       55.000000
# Name: experience_yrs, dtype: float64

# %%
# Convert the experience_yrs column to numeric data type
inp0['experience_yrs'] = pd.to_numeric(inp0['experience_yrs'])


# Check the quantitative spread of the dataframe
inp0.describe()
# Out:
#        wage_per_hour       union  education_yrs  experience_yrs         age  \
# count     534.000000  534.000000     534.000000      534.000000  534.000000
# mean        9.024064    0.179775      13.018727       17.822097   36.833333
# std         5.139097    0.384360       2.615373       12.379710   11.726573
# min         1.000000    0.000000       2.000000        0.000000   18.000000
# 25%         5.250000    0.000000      12.000000        8.000000   28.000000
# 50%         7.780000    0.000000      12.000000       15.000000   35.000000
# 75%        11.250000    0.000000      15.000000       26.000000   44.000000
# max        44.500000    1.000000      18.000000       55.000000   64.000000
#
#            female        marr       south  manufacturing  construction
# count  534.000000  534.000000  534.000000     534.000000    534.000000
# mean     0.458801    0.655431    0.292135       0.185393      0.044944
# std      0.498767    0.475673    0.455170       0.388981      0.207375
# ...

# %%
# Analyse the wage_per_hour column
inp0['wage_per_hour'].describe()
# Out:
# count    534.000000
# mean       9.024064
# std        5.139097
# min        1.000000
# 25%        5.250000
# 50%        7.780000
# 75%       11.250000
# max       44.500000
# Name: wage_per_hour, dtype: float64

# %%
# Question: Find the 50th percentile (median) of the wage_per_hour column
inp0['wage_per_hour'].median()
# Out:
# 7.78

# %% [markdown]
# #### Sanity Checks

# %% [markdown]
# The data should be logically consistent and factually correct before analysis. Some sanity checks that can be performed on this dataset are:
#
# - Hourly wage (`wage_per_hour`) should be greater than 0.
# - Years of education (`education_yrs`) should be non-negative.
# - Years of work experience (`experience_yrs`) should not exceed the employee's age.
# - Binary variables (`union`, `female`, `marr`, `south`, `manufacturing`, and `construction`) should contain only valid values (0 or 1).

# %%
# Perform the sanity checks on the experience_yrs column
# Check for negative values in the experience_yrs column
inp0[inp0['experience_yrs'] < 0]
# Out:
# Empty DataFrame
# Columns: [wage_per_hour, union, education_yrs, experience_yrs, age, female, marr, south, manufacturing, construction]
# Index: []

# %%
# Perform the sanity checks on the wage_per_hour column
inp0[inp0['wage_per_hour'] <= 0]
# Out:
# Empty DataFrame
# Columns: [wage_per_hour, union, education_yrs, experience_yrs, age, female, marr, south, manufacturing, construction]
# Index: []

# %% [markdown]
# #### Outliers Analysis Using Boxplot

# %% [markdown]
# ## Outlier Analysis
#
# Outliers are extreme values that differ significantly from the rest of the observations. These values can influence statistical analysis and may lead to misleading conclusions. Therefore, it is important to identify and examine outliers before proceeding with further analysis.
#
# A **box plot** is one of the most effective visualizations for detecting outliers in numerical variables. It provides a clear view of the data distribution, median, quartiles, and any observations that lie far outside the typical range.
#
# In this dataset, outlier analysis can be performed on numerical variables such as:
# - `wage_per_hour`
# - `education_yrs`
# - `experience_yrs`
# - `age`
#
# Outliers may occur due to:
# - Data entry or measurement errors.
# - Genuine but uncommon observations.
#
# If outliers are caused by incorrect or invalid data, they should be removed or corrected. However, if they represent genuine observations, they should be carefully evaluated before deciding whether to retain or remove them, as they may contain valuable information.
#
# Use box plots to identify and analyze outliers in the numerical variables before making any decisions regarding their treatment.

# %%
# Import the required libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create a box plot for the wage_per_hour column
sns.boxplot(y=inp0['wage_per_hour'])
plt.title('Box Plot of Wage Per Hour')
plt.show()

# %%
# Check the employees with wage_per_hour greater than 40
inp0[inp0['wage_per_hour'] > 40]
# Out:
#      wage_per_hour  union  education_yrs  experience_yrs  age  female  marr  \
# 170           44.5      0             14               1   21       1     0
#
#      south  manufacturing  construction
# 170      0              0             0

# %%
#Clean the Price column# Check the maximum wage after removing outliers
inp0['wage_per_hour'].max()
# Out:
# 44.5

# %%
# Create a box plot for wage_per_hour (all employees are paid)
sns.boxplot(y=inp0['wage_per_hour'])
plt.title('Box Plot of Wage Per Hour (Paid Employees)')
plt.show()

# %%
# Create working copy of dataset
df = inp0.copy()

# Check wages greater than 30
df[df["wage_per_hour"] > 30]
# Out:
#      wage_per_hour  union  education_yrs  experience_yrs  age  female  marr  \
# 170           44.5      0             14               1   21       1     0
#
#      south  manufacturing  construction
# 170      0              0             0

# %%
# Clean wage_per_hour column again by removing extreme outliers (> 40)
df = df[df["wage_per_hour"] <= 40]

# %% [markdown]
# ### Histograms
#
# Histograms can also be used in conjuction with boxplots for data cleaning and data handling purposes. You can use it to check the spread of a numeric variable. Histograms generally work by bucketing the entire range of values that a particular variable takes to specific __bins__. After that, it uses vertical bars to denote the total number of records in a specific bin, which is also known as its __frequency__.

# %% [markdown]
# ![Histogram](images\Histogram.png)

# %% [markdown]
# You can adjust the number of bins to improve its granularity

# %% [markdown]
# ![Bins change](images\Granular.png)

# %% [markdown]
# You'll be using plt.hist() to plot a histogram. Check out its official documentation:https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html

# %%
# Create a histogram of experience years (replacing Reviews column)
df["experience_yrs"].hist(bins=20)
plt.title("Histogram of Experience Years")
plt.xlabel("Experience (Years)")
plt.ylabel("Frequency")
plt.show()

# %%
# Create a boxplot of experience years (replacing Reviews column)
sns.boxplot(y=df["experience_yrs"])
plt.title("Boxplot of Experience Years")
plt.show()

# %%
# Check records with very high experience (equivalent of 1M reviews logic)
df[df["experience_yrs"] > 40]
# Out:
#      wage_per_hour  union  education_yrs  experience_yrs  age  female  marr  \
# 1             4.95      0              9              42   57       1     1
# 16            8.00      0              7              44   57       0     1
# 21            7.00      1              7              42   55       0     1
# 25            5.75      0              6              45   57       0     1
# 31            4.00      0             12              46   64       1     0
# 62            7.00      0              3              55   64       0     1
# 69            6.75      1             10              41   57       0     1
# 75            3.00      1              6              43   55       1     1
# 82            6.10      1             10              44   60       1     0
# 107          14.00      0              5              44   55       0     1
# 109          11.00      0              8              42   56       0     1
# ...

# %%
# Drop records with very high experience (above 40 years)
df = df[df["experience_yrs"] <= 40]

# %%
#Question
# Create histogram again and check peaks for experience years
df["experience_yrs"].hist(bins=20)
plt.title("Histogram of Experience Years (After Cleaning)")
plt.xlabel("Experience (Years)")
plt.ylabel("Frequency")
plt.show()

# %%
#Question- Create box plot for wage_per_hour (replacing Installs column)
sns.boxplot(y=df["wage_per_hour"])
plt.title("Boxplot of Wage per Hour")
plt.show()

# %%
#Question Clean wage_per_hour by removing extremely high values (≥ 100 equivalent threshold logic)
df = df[df["wage_per_hour"] < df["wage_per_hour"].quantile(0.99)]

# %%
# Question-Plot histogram for education years (replacing Size column)
df["education_yrs"].hist(bins=20)
plt.title("Histogram of Education Years")
plt.xlabel("Education (Years)")
plt.ylabel("Frequency")
plt.show()

# %%
#Question -Create boxplot for education years (replacing Size column)
sns.boxplot(y=df["education_yrs"])
plt.title("Boxplot of Education Years")
plt.show()

# %% [markdown]
# ### Session 2 - Data Visualisation with Seaborn

# %% [markdown]
# Seaborn is Python library to create statistical graphs easily. It is built on top of matplotlib and closely integrated with pandas.
#
# _Functionalities of Seaborn_ :
#
# - Dataset oriented API
# - Analysing univariate and bivariate distributions
# - Automatic estimation and plotting of  linear regression models
# - Convenient views for complex datasets
# - Concise control over style
# - Colour palettes

# %%
#import the necessary libraries
# Import the necessary libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Distribution Plots

# %% [markdown]
# A distribution plot is pretty similar to the histogram functionality in matplotlib. Instead of a frequency plot, it plots an approximate probability density for that rating bucket. And the curve (or the __KDE__) that gets drawn over the distribution is the approximate probability density curve.
#
# The following is an example of a distribution plot. Notice that now instead of frequency on the left axis, it has the density for each bin or bucket.

# %% [markdown]
# ![Distplot](images\Distplot.png)

# %% [markdown]
# You'll be using sns.distplot for plotting a distribution plot. Check out its official documentation: https://seaborn.pydata.org/generated/seaborn.distplot.html

# %%
# Create a distribution plot for wage_per_hour

plt.figure(figsize=(8,5))

sns.distplot(df['wage_per_hour'], bins=20, kde=True)

plt.title('Distribution of Hourly Wages')
plt.xlabel('Wage per Hour')
plt.ylabel('Density')

plt.show()
# Out:
# /tmp/ipykernel_1149/1345651599.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['wage_per_hour'], bins=20, kde=True)

# %%
#Change the number of bins


plt.figure(figsize=(8,5))

sns.distplot(df['wage_per_hour'], bins=40, kde=True)

plt.title('Distribution of Hourly Wages (40 Bins)')
plt.xlabel('Wage per Hour')
plt.ylabel('Density')

plt.show()
# Out:
# /tmp/ipykernel_1149/1447771368.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['wage_per_hour'], bins=40, kde=True)

# %%
#Change the colour of bins to green
# Change the colour of bins to green

plt.figure(figsize=(8,5))

sns.distplot(df['wage_per_hour'],
             bins=40,
             kde=True,
             color='green')

plt.title('Distribution of Hourly Wages')
plt.xlabel('Wage per Hour')
plt.ylabel('Density')

plt.show()
# Out:
# /tmp/ipykernel_1149/1909221480.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['wage_per_hour'],

# %%
# Apply matplotlib functionalities

plt.figure(figsize=(10,6))

sns.distplot(df['wage_per_hour'],
             bins=40,
             kde=True,
             color='green')

plt.title('Distribution of Hourly Wages', fontsize=16)
plt.xlabel('Wage per Hour', fontsize=12)
plt.ylabel('Density', fontsize=12)

plt.xlim(0, 25)
plt.grid(True)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()
# Out:
# /tmp/ipykernel_1149/4123466155.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['wage_per_hour'],

# %% [markdown]
# #### Styling Options
#
# One of the biggest advantages of using Seaborn is that you can retain its aesthetic properties and also the Matplotlib functionalities to perform additional customisations. Before we continue with our case study analysis, let’s study some styling options that are available in Seaborn.

# %% [markdown]
# -  Check out the official documentation:https://seaborn.pydata.org/generated/seaborn.set_style.html

# %%
# Set Seaborn style
sns.set_style("darkgrid")

plt.figure(figsize=(10,6))

sns.distplot(df['wage_per_hour'],
             bins=40,
             kde=True,
             color='green')

plt.title('Distribution of Hourly Wages')
plt.xlabel('Wage per Hour')
plt.ylabel('Density')

plt.show()
# Out:
# /tmp/ipykernel_1149/766656743.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['wage_per_hour'],

# %%
# Change the number of bins to 20

sns.set_style("darkgrid")

plt.figure(figsize=(10,6))

sns.distplot(df['wage_per_hour'],
             bins=20,
             kde=True,
             color='green')

plt.title('Distribution of Hourly Wages')
plt.xlabel('Wage per Hour')
plt.ylabel('Density')

plt.show()
# Out:
# /tmp/ipykernel_1149/2130599939.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['wage_per_hour'],

# %% [markdown]
# #### Pie-Chart and Bar Chart

# %% [markdown]
# For analysing how a numeric variable changes across several categories of a categorical variable you utilise either a pie chart or a box plot

# %% [markdown]
# For example, if you want to visualise the responses of a marketing campaign, you can use the following views:

# %% [markdown]
# ![PieChart](images\pie.png)

# %% [markdown]
# ![barChart](images\bar.png)

# %% [markdown]
# - You'll be using the pandas method of plotting both a pie chart and a bar chart. Check out their official documentations:
#    - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html
#    - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html

# %%
# Analyse the union column

df['union'].value_counts().plot.bar(figsize=(6,5))

plt.title('Distribution of Union Membership')
plt.xlabel('Union')
plt.ylabel('Count')

plt.show()

# %%
# Remove the rows with values which are less represented

threshold = 10

counts = df['union'].value_counts()

df = df[df['union'].isin(counts[counts >= threshold].index)]

df['union'].value_counts()
# Out:
# union
# 0    404
# 1     83
# Name: count, dtype: int64

# %%
# Reset the index

df.reset_index(drop=True, inplace=True)

# Display the first few rows
df.head()
# Out:
#    wage_per_hour  union  education_yrs  experience_yrs  age  female  marr  \
# 0           5.10      0              8              21   35       1     1
# 1           6.67      0             12               1   19       0     0
# 2           4.00      0             12               4   22       0     0
# 3           7.50      0             12              17   35       0     1
# 4          13.07      1             13               9   28       0     0
#
#    south  manufacturing  construction
# 0      0              1             0
# 1      0              1             0
# 2      0              0             0
# 3      0              0             0
# 4      0              0             0

# %%
# Count observations in each union category

df['union'].value_counts()
# Out:
# union
# 0    404
# 1     83
# Name: count, dtype: int64

# %%
# Plot a pie chart

df['union'].value_counts().plot.pie(
    figsize=(6,6),
    autopct='%1.1f%%',
    startangle=90,
    labels=['Not in Union', 'Union']
)

plt.title('Distribution of Union Membership')
plt.ylabel('')   # Removes the default 'union' label

plt.show()

# %%
# Plot a bar chart

df['union'].value_counts().plot.bar(
    figsize=(6,5),
    color=['skyblue', 'orange']
)

plt.title('Distribution of Union Membership')
plt.xlabel('Union Membership')
plt.ylabel('Count')
plt.xticks([0, 1], ['Not in Union', 'Union'], rotation=0)

plt.show()

# %%
# Plot a bar chart for education years

df['education_yrs'].value_counts().sort_index().plot(
    kind='bar',
    figsize=(8,5),
    color='skyblue'
)

plt.title('Distribution of Education Years')
plt.xlabel('Years of Education')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# #### Scatter Plots

# %% [markdown]
# Scatterplots are perhaps one of the most commonly used as well one of the most powerful visualisations you can use in the field of machine learning. They are pretty crucial in revealing relationships between the data points and you can generally deduce some sort of trends in the data with the help of a scatter plot.

# %% [markdown]
# ![Scatterplot](images\scatter.png)

# %% [markdown]
# - They're pretty useful in regression problems to check whether a linear trend exists in the data or not. For example, in the image below, creating a linear model in the first case makes far more sense since a clear straight line trend is visible.

# %% [markdown]
# ![Scatterplot-Reg](images\regression3.png)

# %% [markdown]
# - Also, they help in observing __naturally occuring clusters__. In the following image, the marks of students in Maths and Biology has been plotted.You can clearly group the students to 4 clusters now. Cluster 1 are students who score very well in Biology but very poorly in Maths, Cluster 2 are students who score equally well in both the subjects and so on.

# %% [markdown]
# ![Scatter-Clusters](images\Clusters.png)

# %% [markdown]
# **Note**: You'll be studying about both Regression and Clustering in greater detail in the machine learning modules

# %% [markdown]
# You'll be using **sns.jointplot()** for creating a scatter plot. Check out its documentation:
# https://seaborn.pydata.org/generated/seaborn.jointplot.html

# %%
# Plot a scatter plot in the matplotlib way between Experience and Wage

plt.figure(figsize=(8,6))

plt.scatter(df['experience_yrs'], df['wage_per_hour'], color='blue', alpha=0.6)

plt.title('Experience vs Wage per Hour')
plt.xlabel('Experience (Years)')
plt.ylabel('Wage per Hour')

plt.show()

# %%
# Plot the same thing now using a jointplot

sns.jointplot(
    x='experience_yrs',
    y='wage_per_hour',
    data=df,
    kind='scatter',
    height=6
)

plt.show()

# %%
# Plot a jointplot between Education Years and Wage per Hour

sns.jointplot(
    x='education_yrs',
    y='wage_per_hour',
    data=df,
    kind='scatter',
    height=6
)

plt.show()

# %% [markdown]
# **Reg Plots**
#
# - These are an extension to the jointplots, where a regression line is added to the view

# %%
# Plot a reg plot between Education Years and Wage per Hour

plt.figure(figsize=(8,6))

sns.regplot(
    x='education_yrs',
    y='wage_per_hour',
    data=df,
    scatter_kws={'alpha':0.6},
    line_kws={'color':'red'}
)

plt.title('Education Years vs Wage per Hour')
plt.xlabel('Education (Years)')
plt.ylabel('Wage per Hour')

plt.show()

# %%
# Plot a reg plot for only union members

plt.figure(figsize=(8,6))

sns.regplot(
    x='education_yrs',
    y='wage_per_hour',
    data=df[df['union'] == 1],
    scatter_kws={'alpha':0.6},
    line_kws={'color':'red'}
)

plt.title('Education vs Wage (Union Members Only)')
plt.xlabel('Education (Years)')
plt.ylabel('Wage per Hour')

plt.show()

# %% [markdown]
# **Pair Plots**

# %% [markdown]
#  - When you have several numeric variables, making multiple scatter plots becomes rather tedious. Therefore, a pair plot visualisation is preferred where all the scatter plots are in a single view in the form of a matrix
#  - For the non-diagonal views, it plots a **scatter plot** between 2 numeric variables
#  - For the diagonal views, it plots a **histogram**

# %% [markdown]
# Pair Plots help in identifying the trends between a target variable and the predictor variables pretty quickly. For example, say you want to predict how your company’s profits are affected by three different factors. In order to choose which you created a pair plot containing profits and the three different factors as the variables. Here are the scatterplots of profits vs the three variables that you obtained from the pair plot.

# %% [markdown]
# ![Pairplots](images\pairplots2.png)

# %% [markdown]
# It is clearly visible that the left-most factor is the most prominently related to the profits, given how linearly scattered the points are and how randomly scattered the rest two factors are.

# %% [markdown]
# You'll be using **sns.pairplot()** for this visualisation. Check out its official documentation:https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
# Create a pair plot for the numerical variables

sns.pairplot(df[['wage_per_hour',
                 'education_yrs',
                 'experience_yrs',
                 'age']])

plt.show()

# %% [markdown]
# **Bar Charts Revisited**

# %% [markdown]
# - Here, you'll be using bar charts once again, this time using the **sns.barplot()** function. Check out its official documentation:https://seaborn.pydata.org/generated/seaborn.barplot.html
# - You can modify the **estimator** parameter to change the aggregation value of your barplot

# %%
# Plot a bar plot of Union vs Average Wage

avg_wage = df.groupby('union')['wage_per_hour'].mean().reset_index()

sns.barplot(x='union', y='wage_per_hour', data=avg_wage)

plt.title('Average Hourly Wage by Union Membership')
plt.xlabel('Union Membership')
plt.ylabel('Average Wage per Hour')
plt.xticks([0, 1], ['Not in Union', 'Union'])

plt.show()

# %%
# Plot the bar plot with Median Wage

median_wage = df.groupby('union')['wage_per_hour'].median().reset_index()

sns.barplot(x='union', y='wage_per_hour', data=median_wage)

plt.title('Median Hourly Wage by Union Membership')
plt.xlabel('Union Membership')
plt.ylabel('Median Wage per Hour')
plt.xticks([0, 1], ['Not in Union', 'Union'])

plt.show()

# %%
# Plot the bar plot using the estimator parameter

import numpy as np

plt.figure(figsize=(6,5))

sns.barplot(
    x='union',
    y='wage_per_hour',
    data=df,
    estimator=np.median
)

plt.title('Median Hourly Wage by Union Membership')
plt.xlabel('Union Membership')
plt.ylabel('Median Wage per Hour')
plt.xticks([0, 1], ['Not in Union', 'Union'])

plt.show()

# %%
# Plot the bar plot using the estimator parameter

import numpy as np

plt.figure(figsize=(6,5))

sns.barplot(
    x='union',
    y='wage_per_hour',
    data=df,
    estimator=np.median
)

plt.title('Median Hourly Wage by Union Membership')
plt.xlabel('Union Membership')
plt.ylabel('Median Wage per Hour')
plt.xticks([0, 1], ['Not in Union', 'Union'])

plt.show()

# %% [markdown]
# __Box Plots Revisited__
#
# - Apart from outlier analysis, box plots are great at comparing the spread and analysing a numerical variable across several categories
# - Here you'll be using **sns.boxplot()** function to plot the visualisation. Check out its documentation: https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
# Plot a box plot of Wage per Hour vs Union Membership

plt.figure(figsize=(8,6))

sns.boxplot(
    x='union',
    y='wage_per_hour',
    data=df
)

plt.title('Hourly Wage by Union Membership')
plt.xlabel('Union Membership')
plt.ylabel('Wage per Hour')
plt.xticks([0, 1], ['Not in Union', 'Union'])

plt.show()

# %% [markdown]
# #### Heat Maps

# %% [markdown]
# Heat mapsutilise the concept of using colours and colour intensities to visualise a range of values. You must have seen heat maps in cricket or football broadcasts on television to denote the players’ areas of strength and weakness.

# %% [markdown]
# ![HeatMap](images\heatmap1.png)

# %% [markdown]
# - In python, you can create a heat map whenever you have a rectangular grid or table of numbers analysing any two features

# %% [markdown]
# ![heatmap2](images\heatmap2.png)

# %% [markdown]
# - You'll be using **sns.heatmap()** to plot the visualisation. Checkout its official documentation :https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
# Prepare buckets for the Experience Years column using pd.qcut

df['Experience_Bucket'] = pd.qcut(
    df['experience_yrs'],
    q=4,
    labels=['Low', 'Medium', 'High', 'Very High']
)

df[['experience_yrs', 'Experience_Bucket']].head()
# Out:
#    experience_yrs Experience_Bucket
# 0              21              High
# 1               1               Low
# 2               4               Low
# 3              17              High
# 4               9            Medium

# %%
# Create a pivot table for Experience_Bucket and Union with values as Wage per Hour

pivot_table = df.pivot_table(
    values='wage_per_hour',
    index='Experience_Bucket',
    columns='union',
    aggfunc='mean'
)

pivot_table
# Out:
# /tmp/ipykernel_1149/1774367674.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table = df.pivot_table(
# union                     0          1
# Experience_Bucket
# Low                6.652810   7.728750
# Medium             9.475408  12.245000
# High               8.916522  10.883810
# Very High          8.648172  11.738846

# %%
# Change the aggregation to median

pivot_table = df.pivot_table(
    values='wage_per_hour',
    index='Experience_Bucket',
    columns='union',
    aggfunc='median'
)

pivot_table
# Out:
# /tmp/ipykernel_1149/3430726264.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table = df.pivot_table(
# union                  0       1
# Experience_Bucket
# Low                5.650   8.100
# Medium             8.825  12.485
# High               7.830  11.500
# Very High          7.500  10.100

# %%
# Change the aggregation to 20th percentile

pivot_table = df.pivot_table(
    values='wage_per_hour',
    index='Experience_Bucket',
    columns='union',
    aggfunc=lambda x: x.quantile(0.20)
)

pivot_table
# Out:
# /tmp/ipykernel_1149/3827997415.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table = df.pivot_table(
# union                  0     1
# Experience_Bucket
# Low                4.000  5.15
# Medium             5.246  9.50
# High               5.130  8.89
# Very High          4.602  8.00

# %%
# Store the pivot table in a separate variable

pivot_table = df.pivot_table(
    values='wage_per_hour',
    index='Experience_Bucket',
    columns='union',
    aggfunc=lambda x: x.quantile(0.20)
)

pivot_table
# Out:
# /tmp/ipykernel_1149/1701989111.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table = df.pivot_table(
# union                  0     1
# Experience_Bucket
# Low                4.000  5.15
# Medium             5.246  9.50
# High               5.130  8.89
# Very High          4.602  8.00

# %%
##Plot a heat map

# %%
##Apply customisations

# %%
##Question - Replace Content Rating with Review_buckets in the above heat map
##Keep the aggregation at minimum value for Rating

# %% [markdown]
# ### Session 3: Additional Visualisations

# %% [markdown]
# #### Line Plots

# %% [markdown]
# - A line plot tries to observe trends using time dependent data.
# -  For this part, you'll be using **pd.to_datetime()** function. Check out its documentation:https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html

# %%
## Extract the month from the Last Updated Date

# %%
## Find the average Rating across all the months

# %%
## Plot a line graph

# %% [markdown]
# #### Stacked Bar Charts

# %% [markdown]
# - A stacked bar chart breaks down each bar of the bar chart on the basis of a different category
# - For example, for the Campaign Response bar chart you saw earlier, the stacked bar chart is also showing the Gender bifurcation as well

# %% [markdown]
# ![Stacked](images\stacked.png)

# %%
## Create a pivot table for Content Rating and updated Month with the values set to Installs

# %%
##Store the table in a separate variable

# %%
##Plot the stacked bar chart.

# %%
##Plot the stacked bar chart again wrt to the proportions.

# %% [markdown]
# #### Plotly

# %% [markdown]
# Plotly is a Python library used for creating interactive visual charts. You can take a look at how you can use it to create aesthetic looking plots with a lot of user-friendly functionalities like hover, zoom, etc.

# %% [markdown]
# Check out this link for installation and documentation:https://plot.ly/python/getting-started/

# %%
#Install plotly

# %%
#Take the table you want to plot in a separate variable

# %%
#Import the plotly libraries

# %%
#Prepare the plot
